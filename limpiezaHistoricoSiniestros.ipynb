# %% [markdown]
# # 1: Importamos Librerías:

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import geopandas as gpd

# %% [markdown]
# # 2: Cargando base de datos

# %%
#Importamos el archivo
colisiones = pd.read_csv('historico_siniestros_bogota_d.c_-.csv')

# %%
#Hioce este ejercicio para comprobar si podíamos extraer la data directamente desde la URL
#colisiones_prueba = pd.read_csv('https://datosabiertos.bogota.gov.co/dataset/8624f916-1db2-4c17-b669-19a19b35d1ca/resource/f5862aaa-4e1c-463e-94d5-f04db8164360/download/historico_siniestros_bogota_d.c_-.csv')
#colisiones_prueba.tail(10)

# %% [markdown]
# # 3: Análisis Exploratorio

# %% [markdown]
# ### 3.1 Cantidad de registros:

# %%
registros = len(colisiones)
print(f""" Hay un total de {registros} registros en el dataset""")
# Out:
#  Hay un total de 199146 registros en el dataset

# %% [markdown]
# ### 3.2 Cantidad de variables:

# %%
variables = len(colisiones.columns)
print(f""" Hay un total de {variables} columnas en el dataset""")
# Out:
#  Hay un total de 16 columnas en el dataset

# %% [markdown]
# ### 3.3 Tipos de variables

# %%
colisiones.info()
print('\n')
categoricas = []
numericas = []
for columna in colisiones.columns:
    # Verificar si la columna es categórica y tiene más de 2 niveles
    if colisiones[columna].dtype == 'object' and len(colisiones[columna]) > 1:
        categoricas.append(columna)
    else:
      numericas.append(columna)

print(f""" Con respecto a los tipos de variables tenemos: \n
Hay {len(categoricas)} variables categoricas y son_ {categoricas} \n
Hay {len(numericas)} variables numericas y son: {numericas} """)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199146 entries, 0 to 199145
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   X                     199146 non-null  float64
#  1   Y                     199146 non-null  float64
#  2   OBJECTID              199146 non-null  int64
#  3   FORMULARIO            199146 non-null  object
#  4   CODIGO_ACCIDENTE      199146 non-null  int64
#  5   FECHA_OCURRENCIA_ACC  199146 non-null  object
#  6   ANO_OCURRENCIA_ACC    199146 non-null  int64
#  7   DIRECCION             199146 non-null  object
#  8   GRAVEDAD              199146 non-null  object
#  9   CLASE_ACC             199146 non-null  object
#  10  LOCALIDAD             199100 non-null  object
#  11  FECHA_HORA_ACC        199146 non-null  object
#  12  LATITUD               199146 non-null  float64
#  13  LONGITUD              199146 non-null  float64
#  14  CIV                   197445 non-null  float64
#  15  PK_CALZADA            161172 non-null  float64
# dtypes: float64(6), int64(3), object(7)
# memory usage: 24.3+ MB
#
#
#  Con respecto a los tipos de variables tenemos:
#
# Hay 7 variables categoricas y son_ ['FORMULARIO', 'FECHA_OCURRENCIA_ACC', 'DIRECCION', 'GRAVEDAD', 'CLASE_ACC', 'LOCALIDAD', 'FECHA_HORA_ACC']
#
# Hay 9 variables numericas y son: ['X', 'Y', 'OBJECTID', 'CODIGO_ACCIDENTE', 'ANO_OCURRENCIA_ACC', 'LATITUD', 'LONGITUD', 'CIV', 'PK_CALZADA']

# %% [markdown]
# ### 3.4 Estadística Descriptiva del dataset

# %%
colisiones.describe().T
# Out:
#                        count          mean           std           min  \
# X                   199146.0 -7.410410e+01  4.009853e-02 -7.422830e+01
# Y                   199146.0  4.649135e+00  5.756745e-02  4.085800e+00
# OBJECTID            199146.0  2.461163e+05  1.282976e+05  1.000000e+00
# CODIGO_ACCIDENTE    199146.0  7.368238e+06  3.017820e+06  4.401420e+06
# ANO_OCURRENCIA_ACC  199146.0  2.017760e+03  1.855071e+00  2.015000e+03
# LATITUD             199146.0  4.649135e+00  5.756745e-02  4.085800e+00
# LONGITUD            199146.0 -7.410410e+01  4.009855e-02 -7.422830e+01
# CIV                 197445.0  1.379895e+07  1.346756e+07  0.000000e+00
# PK_CALZADA          161172.0  7.588678e+06  1.840877e+07  0.000000e+00
#
#                              25%           50%           75%           max
# X                  -7.413420e+01 -7.410304e+01 -7.407301e+01 -7.401100e+01
# Y                   4.608163e+00  4.645415e+00  4.690015e+00  4.828041e+00
# OBJECTID            1.356038e+05  2.830275e+05  3.581768e+05  4.219110e+05
# CODIGO_ACCIDENTE    4.458053e+06  4.512848e+06  1.049794e+07  1.054926e+07
# ANO_OCURRENCIA_ACC  2.016000e+03  2.018000e+03  2.019000e+03  2.021000e+03
# LATITUD             4.608163e+00  4.645415e+00  4.690015e+00  4.828041e+00
# LONGITUD           -7.413420e+01 -7.410304e+01 -7.407301e+01 -7.401100e+01
# CIV                 7.004943e+06  1.000758e+07  1.500116e+07  5.000962e+07
# PK_CALZADA          4.326700e+04  1.769000e+05  2.354850e+05  9.103049e+07

# %% [markdown]
# ### 3.5 Verificación datos nulos.

# %%
registros_Nulos = colisiones.isnull().sum()
print(f""" Nos damos cuenta de que hay algunas columnas: \n

LOCALIDAD
CIV
PK_CALZADA
\n
que tienen presencia de null values""")
# Out:
#  Nos damos cuenta de que hay algunas columnas:
#
#
# LOCALIDAD
# CIV
# PK_CALZADA
#
#
# que tienen presencia de null values

# %% [markdown]
# ### 3.6 Verificación de registros duplicados

# %%
duplicated = colisiones[colisiones.duplicated(keep='first')] #Dataframe de registros duplicados
print(f""" Hay un total de {len(duplicated)} registros duplicados>""")
# Out:
#  Hay un total de 0 registros duplicados>

# %% [markdown]
# ### 3.7 Borrado de columnas no apropiadas para modelamiento
#
# Para esto debemos tener a consideración lo siguiente:
#
# 1. Qué significa cada variable?
# 2. El tipo de dato que representa es acorde a como Pandas lo detecta inicialmente?
# 3. La presencia de null values es indicio de que debería ser eliminada?

# %%
colisiones.tail(20)
# Out:
#                 X         Y  OBJECTID  FORMULARIO  CODIGO_ACCIDENTE  \
# 199126 -74.130000  4.646000    421892  A001297005          10537173
# 199127 -74.134000  4.630000    421893  A001299614          10539404
# 199128 -74.159000  4.641000    421894  A001237779          10535569
# 199129 -74.171000  4.631000    421895  A001296900          10537769
# 199130 -74.138000  4.632000    421896  A001340409          10547678
# 199131 -74.156000  4.625000    421897  A001306094          10546703
# 199132 -74.168000  4.631000    421898  A001341515          10548679
# 199133 -74.141000  4.614000    421899  A001339384          10547047
# 199134 -74.154000  4.613000    421900  A001297651          10538759
# 199135 -74.141000  4.609000    421901  A001240637          10533577
# 199136 -74.171000  4.628000    421902  A001298808          10540139
# 199137 -74.137864  4.626886    421903  A001301685          10542512
# 199138 -74.140587  4.615627    421904  A001241254          10534370
# 199139 -74.158000  4.628000    421905  A001339673          10547144
# 199140 -74.141000  4.610000    421906  A001340014          10547398
# 199141 -74.160000  4.637000    421907  A001341297          10548522
# 199142 -74.167000  4.628000    421908  A001305748          10546116
# 199134             CHOQUE   KENNEDY  2021/04/26 07:20:00+00  4.613000
# 199135             CHOQUE   KENNEDY  2021/02/18 16:29:00+00  4.609000
# 199136             CHOQUE   KENNEDY  2021/05/16 23:30:00+00  4.628000
# 199137             CHOQUE   KENNEDY  2021/06/20 06:15:00+00  4.626886
# 199138        VOLCAMIENTO   KENNEDY  2021/02/28 01:50:00+00  4.615627
# 199139             CHOQUE   KENNEDY  2021/08/14 15:53:00+00  4.628000
# 199140             CHOQUE   KENNEDY  2021/08/20 01:15:00+00  4.610000
# 199141             CHOQUE   KENNEDY  2021/08/30 16:31:00+00  4.637000
# 199142          ATROPELLO   KENNEDY  2021/08/03 14:00:00+00  4.628000
# 199143             CHOQUE   KENNEDY  2021/03/19 12:50:00+00  4.624830
# 199144             CHOQUE   KENNEDY  2021/04/18 21:21:00+00  4.622000
# 199145  CAIDA DE OCUPANTE   KENNEDY  2021/07/12 19:53:00+00  4.630000
#
#          LONGITUD         CIV  PK_CALZADA
# 199126 -74.130000  50002371.0         NaN
# 199127 -74.134000   8004594.0         NaN
# 199128 -74.159000   8002100.0         NaN
# 199129 -74.171000   8004442.0         NaN
# 199130 -74.138000  50006521.0         NaN
# 199131 -74.156000         NaN         NaN
# 199132 -74.168000   8004537.0         NaN
# 199133 -74.141000   8008510.0         NaN
# 199134 -74.154000   8008637.0         NaN
# 199135 -74.141000   8009745.0         NaN
# 199136 -74.171000   8005072.0         NaN
# 199137 -74.137864   8005344.0         NaN
# 199138 -74.140587   8007974.0         NaN
# 199139 -74.158000  50006497.0         NaN
# 199140 -74.141000   8009540.0         NaN
# 199141 -74.160000   8003090.0         NaN
# 199142 -74.167000   8005066.0         NaN
# 199143 -74.158247   8005839.0         NaN
# 199144 -74.167000   8011660.0         NaN
# 199145 -74.168000   8004623.0         NaN

# %% [markdown]
# Teniendo en consideración las pautas anteriores, tomamos la decisión de eliminar las tres primeras columnas:
# - X
# - Y
# - OBJECTID
#
# Esto debido a que X e Y, al hacer referencia a coordenadas geográficas decimales en longitud y latitud, ya están representadas en las columnasLATITUD y LONGITUD.
#
# Además, OBJECTID hace referencia a un identificador único, por lo cuál NO es necesario que lo tengamos en cuenta

# %%
colisiones.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'FORMULARIO', 'CODIGO_ACCIDENTE',
#        'FECHA_OCURRENCIA_ACC', 'ANO_OCURRENCIA_ACC', 'DIRECCION', 'GRAVEDAD',
#        'CLASE_ACC', 'LOCALIDAD', 'FECHA_HORA_ACC', 'LATITUD', 'LONGITUD',
#        'CIV', 'PK_CALZADA'],
#       dtype='object')

# %%
colisiones.drop(columns=['X','Y','OBJECTID'],inplace=True)

# %%
colisiones.tail(10)
# Out:
#         FORMULARIO  CODIGO_ACCIDENTE    FECHA_OCURRENCIA_ACC  \
# 199136  A001298808          10540139  2021/05/16 00:00:00+00
# 199137  A001301685          10542512  2021/06/20 00:00:00+00
# 199138  A001241254          10534370  2021/02/28 00:00:00+00
# 199139  A001339673          10547144  2021/08/14 00:00:00+00
# 199140  A001340014          10547398  2021/08/20 00:00:00+00
# 199141  A001341297          10548522  2021/08/30 00:00:00+00
# 199142  A001305748          10546116  2021/08/03 00:00:00+00
# 199143  A001238302          10536074  2021/03/19 00:00:00+00
# 199144  A001297106          10538181  2021/04/18 00:00:00+00
# 199145  A001304271          10544226  2021/07/12 00:00:00+00
#
#         ANO_OCURRENCIA_ACC                                       DIRECCION  \
# 199136                2021  KR 86  - AV AVENIDA CIUDAD DE VILLAVICENCIO 02
# 199137                2021                  AV AVENIDA BOYACA - CL 3 B  18
# 199138                2021                              KR 72 - CL 35 S 79
# 199139                2021                            KR 80  - CL 38  S 02
# 199140                2021                            KR 72  - CL 38  S 02
# 199141                2021                          KR 86 F  - CL 33  S 02
# 199142                2021                         CL 42 B  S- KR 81 L  02
# 199143                2021                                DG 2 S- KR 79 12
# 199144                2021                               CL 43 S- KR 80 02
# 199145                2021         AV AVENIDA CIUDAD DE CALI - CL 42  S 02
#
#            GRAVEDAD          CLASE_ACC LOCALIDAD          FECHA_HORA_ACC  \
# 199136   SOLO DANOS             CHOQUE   KENNEDY  2021/05/16 23:30:00+00
# 199137  CON HERIDOS             CHOQUE   KENNEDY  2021/06/20 06:15:00+00
# 199138  CON HERIDOS        VOLCAMIENTO   KENNEDY  2021/02/28 01:50:00+00
# 199139   SOLO DANOS             CHOQUE   KENNEDY  2021/08/14 15:53:00+00
# 199140   SOLO DANOS             CHOQUE   KENNEDY  2021/08/20 01:15:00+00
# 199141   SOLO DANOS             CHOQUE   KENNEDY  2021/08/30 16:31:00+00
# 199142  CON HERIDOS          ATROPELLO   KENNEDY  2021/08/03 14:00:00+00
# 199143  CON HERIDOS             CHOQUE   KENNEDY  2021/03/19 12:50:00+00
# 199144  CON HERIDOS             CHOQUE   KENNEDY  2021/04/18 21:21:00+00
# 199145  CON HERIDOS  CAIDA DE OCUPANTE   KENNEDY  2021/07/12 19:53:00+00
#
#          LATITUD   LONGITUD         CIV  PK_CALZADA
# 199136  4.628000 -74.171000   8005072.0         NaN
# 199137  4.626886 -74.137864   8005344.0         NaN
# 199138  4.615627 -74.140587   8007974.0         NaN
# 199139  4.628000 -74.158000  50006497.0         NaN
# 199140  4.610000 -74.141000   8009540.0         NaN
# 199141  4.637000 -74.160000   8003090.0         NaN
# 199142  4.628000 -74.167000   8005066.0         NaN
# 199143  4.624830 -74.158247   8005839.0         NaN
# 199144  4.622000 -74.167000   8011660.0         NaN
# 199145  4.630000 -74.168000   8004623.0         NaN

# %%
#Adicionalmente, debido a que en la columna 'PK_CALZADA' tenemos varios registros que aparecen como Nan, podemos reemplazarlos con 
#un valor más explicativo, ya qie no podemos borrar el registro
colisiones['PK_CALZADA'] = colisiones['PK_CALZADA'].fillna('SIN CALZADA')
colisiones.tail(10)
# Out:
#         FORMULARIO  CODIGO_ACCIDENTE    FECHA_OCURRENCIA_ACC  \
# 199136  A001298808          10540139  2021/05/16 00:00:00+00
# 199137  A001301685          10542512  2021/06/20 00:00:00+00
# 199138  A001241254          10534370  2021/02/28 00:00:00+00
# 199139  A001339673          10547144  2021/08/14 00:00:00+00
# 199140  A001340014          10547398  2021/08/20 00:00:00+00
# 199141  A001341297          10548522  2021/08/30 00:00:00+00
# 199142  A001305748          10546116  2021/08/03 00:00:00+00
# 199143  A001238302          10536074  2021/03/19 00:00:00+00
# 199144  A001297106          10538181  2021/04/18 00:00:00+00
# 199145  A001304271          10544226  2021/07/12 00:00:00+00
#
#         ANO_OCURRENCIA_ACC                                       DIRECCION  \
# 199136                2021  KR 86  - AV AVENIDA CIUDAD DE VILLAVICENCIO 02
# 199137                2021                  AV AVENIDA BOYACA - CL 3 B  18
# 199138                2021                              KR 72 - CL 35 S 79
# 199139                2021                            KR 80  - CL 38  S 02
# 199140                2021                            KR 72  - CL 38  S 02
# 199141                2021                          KR 86 F  - CL 33  S 02
# 199142                2021                         CL 42 B  S- KR 81 L  02
# 199143                2021                                DG 2 S- KR 79 12
# 199144                2021                               CL 43 S- KR 80 02
# 199145                2021         AV AVENIDA CIUDAD DE CALI - CL 42  S 02
#
#            GRAVEDAD          CLASE_ACC LOCALIDAD          FECHA_HORA_ACC  \
# 199136   SOLO DANOS             CHOQUE   KENNEDY  2021/05/16 23:30:00+00
# 199137  CON HERIDOS             CHOQUE   KENNEDY  2021/06/20 06:15:00+00
# 199138  CON HERIDOS        VOLCAMIENTO   KENNEDY  2021/02/28 01:50:00+00
# 199139   SOLO DANOS             CHOQUE   KENNEDY  2021/08/14 15:53:00+00
# 199140   SOLO DANOS             CHOQUE   KENNEDY  2021/08/20 01:15:00+00
# 199141   SOLO DANOS             CHOQUE   KENNEDY  2021/08/30 16:31:00+00
# 199142  CON HERIDOS          ATROPELLO   KENNEDY  2021/08/03 14:00:00+00
# 199143  CON HERIDOS             CHOQUE   KENNEDY  2021/03/19 12:50:00+00
# 199144  CON HERIDOS             CHOQUE   KENNEDY  2021/04/18 21:21:00+00
# 199145  CON HERIDOS  CAIDA DE OCUPANTE   KENNEDY  2021/07/12 19:53:00+00
#
#          LATITUD   LONGITUD         CIV   PK_CALZADA
# 199136  4.628000 -74.171000   8005072.0  SIN CALZADA
# 199137  4.626886 -74.137864   8005344.0  SIN CALZADA
# 199138  4.615627 -74.140587   8007974.0  SIN CALZADA
# 199139  4.628000 -74.158000  50006497.0  SIN CALZADA
# 199140  4.610000 -74.141000   8009540.0  SIN CALZADA
# 199141  4.637000 -74.160000   8003090.0  SIN CALZADA
# 199142  4.628000 -74.167000   8005066.0  SIN CALZADA
# 199143  4.624830 -74.158247   8005839.0  SIN CALZADA
# 199144  4.622000 -74.167000   8011660.0  SIN CALZADA
# 199145  4.630000 -74.168000   8004623.0  SIN CALZADA

# %%
#Adicionalmente nos damos cuenta que la columna de fechas está en formato string: Convirtámosla a fecha y hora
# Convert 'FECHA_HORA_ACC' series to datetime dtype
colisiones['FECHA_HORA_ACC'] = pd.to_datetime(colisiones['FECHA_HORA_ACC'])
colisiones['FECHA_HORA_ACC'].dtype
# Out:
# datetime64[ns, UTC]

# %%
# Creamos dos nuevas Pandas Series
colisiones['FECHA_ACC'] = colisiones['FECHA_HORA_ACC'].dt.date
colisiones['HORA_ACC'] = colisiones['FECHA_HORA_ACC'].dt.time

# %%
#Visualicemos como nos quedó
colisiones.tail(10)
# Out:
#         FORMULARIO  CODIGO_ACCIDENTE    FECHA_OCURRENCIA_ACC  \
